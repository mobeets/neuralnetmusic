# %%
import numpy as np
import os.path
import music21
import midiparser
import midi
import midiparser2
import glob
import cPickle
NUMPY_DTYPE = np.float64

# %%
filename = 'output/example.mid'
s = music21.converter.parse(filename)
s.show()

# %%
filename = 'output/example_2.mid'
s = music21.converter.parse(filename)
s.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-e48735e06bc9> in <module>()
#       1 filename = 'output/example_2.mid'
#       2 s = music21.converter.parse(filename)
# ----> 3 s.show()
#
# /Users/mobeets/anaconda/lib/python2.7/site-packages/music21/base.pyc in show(self, fmt, app, **keywords)
#    2374                                  app=app,
#    2375                                  subformats=subformats,
# -> 2376                                  **keywords)
#    2377
#    2378     #--------------------------------------------------------------------------
#
# /Users/mobeets/anaconda/lib/python2.7/site-packages/music21/converter/subConverters.pyc in show(self, obj, fmt, app, subformats, **keywords)
#     277
#     278         if 'Opus' not in obj.classes:
# --> 279             fp = helperSubConverter.write(obj, helperFormat, subformats=helperSubformats)
#     280
#     281             defaults.title = savedDefaultTitle
#
# /Users/mobeets/anaconda/lib/python2.7/site-packages/music21/converter/subConverters.pyc in write(self, obj, fmt, fp, subformats, **keywords)
#     704
#     705         generalExporter = m21ToXml.GeneralObjectExporter(obj)
# --> 706         dataBytes = generalExporter.parse()
#     707         fp = self.writeDataStream(fp, dataBytes)
#     708
#
# /Users/mobeets/anaconda/lib/python2.7/site-packages/music21/musicxml/m21ToXml.pyc in parse(self, obj)
#     340         if obj is None:
#     341             obj = self.generalObj
# --> 342         outObj = self.fromGeneralObject(obj)
#     343         return self.parseWellformedObject(outObj)
#     344
#
# /Users/mobeets/anaconda/lib/python2.7/site-packages/music21/musicxml/m21ToXml.pyc in fromGeneralObject(self, obj)
#     375             if cM in classes:
#     376                 meth = getattr(self, methName)
# --> 377                 outObj = meth(obj)
#     378                 break
#     379         if outObj is None:
#
# /Users/mobeets/anaconda/lib/python2.7/site-packages/music21/musicxml/m21ToXml.pyc in fromScore(self, sc)
#     386         the best one of all -- a perfectly made Score (or something like that)
#     387         '''
# --> 388         scOut = sc.makeNotation(inPlace=False)
#     389         scOut.makeImmutable()
#     390         return scOut
#
# /Users/mobeets/anaconda/lib/python2.7/site-packages/music21/stream/__init__.pyc in makeNotation(self, meterStream, refStreamOrTimeRange, inPlace, bestClef, **subroutineKeywords)
#   12185                                inPlace=True,
#   12186                                bestClef=bestClef,
# > 12187                                **subroutineKeywords)
#   12188             # note: while the local-streams have updated their caches, the
#   12189             # containing score has an out-of-date cache of flat.
#
# /Users/mobeets/anaconda/lib/python2.7/site-packages/music21/stream/__init__.pyc in makeNotation(self, meterStream, refStreamOrTimeRange, inPlace, bestClef, **subroutineKeywords)
#    5543                 refStreamOrTimeRange=refStreamOrTimeRange,
#    5544                 inPlace=True,
# -> 5545                 bestClef=bestClef)
#    5546
#    5547         measureStream = returnStream.getElementsByClass('Measure')
#
# /Users/mobeets/anaconda/lib/python2.7/site-packages/music21/stream/__init__.pyc in makeMeasures(self, meterStream, refStreamOrTimeRange, searchContext, innerBarline, finalBarline, bestClef, inPlace)
#    5273             finalBarline=finalBarline,
#    5274             bestClef=bestClef,
# -> 5275             inPlace=inPlace,
#    5276             )
#    5277
#
# /Users/mobeets/anaconda/lib/python2.7/site-packages/music21/stream/makeNotation.pyc in makeMeasures(s, meterStream, refStreamOrTimeRange, searchContext, innerBarline, finalBarline, bestClef, inPlace)
#     499         for i in range(len(post)):
#     500             m = post[i]
# --> 501             if m.timeSignature is not None:
#     502                 lastTimeSignature = m.timeSignature
#     503             # get start and end offsets for each measure
#
# /Users/mobeets/anaconda/lib/python2.7/site-packages/music21/stream/__init__.pyc in _getTimeSignature(self)
#   11415         #environLocal.printDebug(['matched Measure classes of type TimeSignature', tsList, len(tsList)])
#   11416         # only return timeSignatures at offset = 0.0
# > 11417         tsList = tsList.getElementsByOffset(0)
#   11418         if len(tsList) == 0:
#   11419             return None
#
# /Users/mobeets/anaconda/lib/python2.7/site-packages/music21/stream/__init__.pyc in getElementsByOffset(self, offsetStart, offsetEnd, includeEndBoundary, mustFinishInSpan, mustBeginInSpan, includeElementsThatEndAtStart, classList)
#    2778         if classList is not None:
#    2779             iterator.getElementsByClass(classList)
# -> 2780         return iterator.stream()
#    2781
#    2782
#
# /Users/mobeets/anaconda/lib/python2.7/site-packages/music21/stream/iterator.pyc in stream(self, returnStreamSubClass)
#     487         if returnStreamSubClass is True:
#     488             try:
# --> 489                 found = ss.__class__()
#     490             except TypeError:
#     491                 found = self._newBaseStream()
#
# /Users/mobeets/anaconda/lib/python2.7/site-packages/music21/stream/__init__.pyc in __init__(self, *args, **keywords)
#   10965
#   10966     def __init__(self, *args, **keywords):
# > 10967         Stream.__init__(self, *args, **keywords)
#   10968
#   10969         # clef and timeSignature is defined as a property below
#
# /Users/mobeets/anaconda/lib/python2.7/site-packages/music21/stream/__init__.pyc in __init__(self, givenElements, *args, **keywords)
#     203     def __init__(self, givenElements=None, *args, **keywords):
#     204         base.Music21Object.__init__(self, **keywords)
# --> 205         core.StreamCoreMixin.__init__(self)
#     206
#     207         self.streamStatus = streamStatus.StreamStatus(self)
#
# /Users/mobeets/anaconda/lib/python2.7/site-packages/music21/stream/core.pyc in __init__(self)
#      32
#      33 class StreamCoreMixin(object):
# ---> 34     def __init__(self):
#      35         self._cache = {}
#      36         # hugely important -- keeps track of where the _elements are
#
# KeyboardInterrupt:

# %%
reload(midiparser)
infile = 'output/example.mid'

roll = midiparser.midiread(infile, desired_resolution=2)
midiparser.midiwrite(roll, infile.replace('.mid', '_2.mid'), resolution=2, pitch_offset=0)

# %%
pattern = midi.read_midifile(infile)

# %%
x = []
y = np.array([[5,4],[4,3]])
x.append(y)
x.append(y)
print
# Out:
# 32

# %%
dd = midiparser2.process_notes(infile)

# %%
reload(midiparser2)
outfile = infile.replace('.mid', '_2.mid')
print dd.shape, outfile
midiparser2.process_notes(dd, outfile)
# Out:
# (252, 4) output/example_2.mid
# array([[   0.        ,   76.        ,    0.49895833,  105.        ],
#        [   0.5       ,   55.        ,    1.49895833,   75.        ],
#        [   0.5       ,   59.        ,    1.49895833,   75.        ],
#        ...,
#        [  46.5       ,   55.        ,    0.24895833,   75.        ],
#        [  46.5       ,   59.        ,    0.24895833,   75.        ],
#        [  46.5       ,   62.        ,    0.24895833,   75.        ]])

# %%
dd.shape
# Out:
# (252, 4)

# %%
train_dir = 'midifiles/train/*.mid'
RESOLUTION = 2
NUM_KEYS = 88
max_len = 64

ds = []
train_files = glob.glob(train_dir)[:10]
for infile in train_files:
    m = midiparser.midiread(infile, desired_resolution=RESOLUTION)
    s = blockwise_view(m, (max_len,NUM_KEYS), require_aligned_blocks=False)[:,0]
    ds.append(s)
    print s.shape
ds = np.vstack(ds)
ds = np.swapaxes(ds, 1, 2)
ds1 = np.reshape(ds, (ds.shape[0], 88*64))
print np.all(ds1[1,:].reshape([88, 64]) == ds[1,:])
# Out:
# (701, 64, 88)
# (727, 64, 88)
# (960, 64, 88)
# (540, 64, 88)
# (290, 64, 88)
# (1582, 64, 88)
# (900, 64, 88)
# (967, 64, 88)
# (337, 64, 88)
# (967, 64, 88)
# True

# %%
data_file = './joplin-data.pickle'
raw_x = cPickle.load(open(data_file, 'rb')).astype(dtype=NUMPY_DTYPE)

# %%
raw_x.shape
# Out:
# (575, 5632)

# %%
88*64
# Out:
# 5632

# %%
def blockwise_view(a, blockshape, require_aligned_blocks=True):
    assert a.flags['C_CONTIGUOUS'], "This function relies on the memory layout of the array."
    blockshape = tuple(blockshape)
    view_shape = tuple(np.array(a.shape) / blockshape) + blockshape
    if require_aligned_blocks:
        assert (np.mod(a.shape, blockshape) == 0).all(), \
            "blockshape {} must divide evenly into array shape {}"\
            .format( blockshape, a.shape )
    intra_block_strides = a.strides
    inter_block_strides = tuple(a.strides * np.array(blockshape))
    return np.lib.stride_tricks.as_strided(a, 
                                              shape=view_shape, 
                                              strides=(inter_block_strides+intra_block_strides))
